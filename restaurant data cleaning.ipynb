# %%
import pandas as pd

data = pd.read_excel("2017 Order Data2.xlsx")

# %%
data
# Out:
#     Order ID                             Customer ID Cookies Shipped  Revenue  \
# 0     413383                 152689 - YT Restaurants             936   4680.0
# 1     751142  985245 - Quick Bite Convenience Stores             987   4935.0
# 2     876056  985245 - Quick Bite Convenience Stores             270   1350.0
# 3     548247  985245 - Quick Bite Convenience Stores             925   4625.0
# 4     626350                 152689 - YT Restaurants             974   4870.0
# ..       ...                                     ...             ...      ...
# 817   800525                 785432 - Park & Eat LLC             164    820.0
# 818   311436  985245 - Quick Bite Convenience Stores             107    535.0
# 819   XXXXXX                          XXXXXX - Promo             904   4520.0
# 820   617865            452584 - Acme Grocery Stores              62    310.0
# 821   154036                325698 - Cascade Grovers             765   3825.0
#
# ...

# %%
data.insert(9, "City", "")

# %%
data.insert(10, "Postal", "")

# %%
data["Order Adress"].str.split(",", expand=True)
# Out:
#                  0               1          2
# 0    136 Church St   New York City   NY 10001
# 1       562 2nd St   New York City   NY 10001
# 2      277 Main St   New York City   NY 10001
# 3       410 6th St   San Francisco   CA 94016
# 4       43 Hill St         Atlanta   GA 30301
# ..             ...             ...        ...
# 817  988 Spruce St          Boston   MA 02215
# 818    969 11th St          Boston   MA 02215
# 819   364 North St          Boston   MA 02215
# 820   364 North St          Boston   MA 02215
# 821    181 12th St          Austin   TX 73301
#
# [822 rows x 3 columns]

# %%
data[["Order Adress", "City", "Postal"]] = data["Order Adress"].str.split(",", expand=True)

# %%
data
# Out:
#     Order ID                             Customer ID Cookies Shipped  Revenue  \
# 0     413383                 152689 - YT Restaurants             936   4680.0
# 1     751142  985245 - Quick Bite Convenience Stores             987   4935.0
# 2     876056  985245 - Quick Bite Convenience Stores             270   1350.0
# 3     548247  985245 - Quick Bite Convenience Stores             925   4625.0
# 4     626350                 152689 - YT Restaurants             974   4870.0
# ..       ...                                     ...             ...      ...
# 817   800525                 785432 - Park & Eat LLC             164    820.0
# 818   311436  985245 - Quick Bite Convenience Stores             107    535.0
# 819   XXXXXX                          XXXXXX - Promo             904   4520.0
# 820   617865            452584 - Acme Grocery Stores              62    310.0
# 821   154036                325698 - Cascade Grovers             765   3825.0
#
# ...
